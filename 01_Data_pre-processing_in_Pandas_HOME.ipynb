# %%
import os

# %%
os.chdir('C:\\Users\\Nick')

# %%
import pandas

# %%
data = pandas.read_csv('titanic.csv', index_col='PassengerId')

# %%
data.head(30)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %%
data['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
data['Survived'].value_counts()/data['Survived'].count()*100
# Out:
# 0    61.616162
# 1    38.383838
# Name: Survived, dtype: float64

# %%
"Percentage of Survived = {:.2f}".format(data['Survived'].where(data.Survived == 1).count() / data['Survived'].count()*100)
# Out:
# 'Percentage of Survived = 38.38'

# %%
"Percentage of 1st class = {:.2f}".format(data['Pclass'].where(data.Pclass == 1).count() / data['Survived'].count()*100)
# Out:
# 'Percentage of 1st class = 24.24'

# %%
str(round(data['Age'].mean(),2)) + " " + str(data['Age'].median())
# Out:
# '29.7 28.0'

# %%
data[['SibSp', 'Parch']].corr()
# Out:
#           SibSp     Parch
# SibSp  1.000000  0.414838
# Parch  0.414838  1.000000
